# %%
#libraries
import pandas as pd

# %%
#variables 
csvfile = 'diabetesDataset.csv'
ignoreColumns = ['Target']

# %%
df = pd.read_csv(csvfile)

# %%
df.drop(columns=ignoreColumns)
# Out:
#       Genetic Markers Autoantibodies Family History Environmental Factors  \
# 0            Positive       Negative             No               Present
# 1            Positive       Negative             No               Present
# 2            Positive       Positive            Yes               Present
# 3            Negative       Positive             No               Present
# 4            Negative       Negative            Yes               Present
# ...               ...            ...            ...                   ...
# 69995        Negative       Negative            Yes               Present
# 69996        Positive       Positive             No                Absent
# 69997        Positive       Negative             No                Absent
# 69998        Positive       Negative             No                Absent
# 69999        Positive       Positive            Yes                Absent
#
#        Insulin Levels  Age  BMI Physical Activity Dietary Habits  \
# ...
